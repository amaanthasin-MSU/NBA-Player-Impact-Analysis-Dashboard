# %% [markdown]
# All data collected was from https://www.nba.com/stats/teams/catch-shoot

# %%
import matplotlib.pyplot as plt

# Data
years = ['2014', '2015', '2016', '2017', '2018', '2019']
catch_shoot_pts = [26.6, 29.6, 33.3, 30.3, 22.8, 24.0]
league_rank = [24, 14, 7, 2, 10, 30]

fig, ax1 = plt.subplots(figsize=(10, 6))

# Axis 1: Catch & Shoot Points
color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Catch & Shoot Points', color=color)
line1 = ax1.plot(years, catch_shoot_pts, color=color, marker='o', label='Catch & Shoot Points')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('League Rank for Catch & Shoot', color=color)
line2 = ax2.plot(years, league_rank, color=color, marker='o', label='League Rank')
ax2.set_ylim(30, 1)  # Inverting the scale so 1 is at top
ax2.tick_params(axis='y', labelcolor=color)

# Combining legends from both axes
lines = line1 + line2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper center')

ax1.set_title('Cleveland Cavaliers Catch & Shoot Points vs. League Rank (2014-2019)')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = ['2014', '2015', '2016', '2017', '2018', '2019']
catch_shoot_pts = [23.7, 26.6, 29.6, 33.3, 30.3, 22.8]  # Hypothetical data for demonstration
league_rank = [24, 14, 7, 2, 10, 30]  # Hypothetical league ranks

fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for catch and shoot points
bars = ax1.bar(years, catch_shoot_pts, color='skyblue', label='Catch & Shoot Points')
ax1.set_xlabel('Year')
ax1.set_ylabel('Catch & Shoot Points')
ax1.set_title('Cleveland Cavaliers Catch & Shoot Performance and League Rank (2014-2019)')

# Create a twin axis for the league rank
ax2 = ax1.twinx()
line = ax2.plot(years, league_rank, color='red', marker='o', linestyle='-', linewidth=2, label='League Rank')
ax2.set_ylabel('League Rank')
ax2.invert_yaxis()  # Invert to show better ranks at the top

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
years = ['2014', '2015', '2016', '2017', '2018', '2019']
league_rank = [24, 14, 7, 2, 10, 30]  # Hypothetical league ranks

fig, ax = plt.subplots(figsize=(10, 6))

# Line chart for league rank
ax.plot(years, league_rank, color='red', marker='o', linestyle='-', linewidth=2, label='League Rank')
ax.set_xlabel('Year')
ax.set_ylabel('League Rank')
ax.set_title('Cleveland Cavaliers League Rank for Catch & Shoot (2014-2019)')
ax.invert_yaxis()  # Invert to show better ranks at the top

# Add a grid for better readability
ax.grid(True, linestyle='--', which='both', alpha=0.5)

# Add legend
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

years = ['2014', '2015', '2016', '2017', '2018', '2019']
catch_shoot_pts = [23.7, 26.6, 29.6, 33.3, 30.3, 22.8]
league_rank = [24, 14, 7, 2, 10, 30]

fig, ax1 = plt.subplots(figsize=(10, 6))

colors = ['skyblue' if year in ['2015', '2016', '2017', '2018'] else 'lightgreen' for year in years]
bar_labels = ['LeBron Played' if color == 'skyblue' else 'Other Years' for color in colors]

for (year, pts, color, label) in zip(years, catch_shoot_pts, colors, bar_labels):
    ax1.bar(year, pts, color=color, label=label if not plt.gca().get_legend_handles_labels()[1].count(label) else "")

ax2 = ax1.twinx()
ax2.plot(years, league_rank, color='magenta', marker='o', linestyle='-', linewidth=2, label='League Rank')
ax2.set_ylabel('League Rank', color='magenta')
ax2.invert_yaxis()


handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()

handles = handles1 + handles2
labels = labels1 + labels2

by_label = dict(zip(labels, handles))


plt.show()

# %%
import pandas as pd
cs_19 = pd.read_csv("catch_shoot_19.csv")
cs_18 = pd.read_csv("catch_shoot_18.csv")
cs_17 = pd.read_csv("catch_shoot_17.csv")
cs_16 = pd.read_csv("catch_shoot_16.csv")
cs_15 = pd.read_csv("catch_shoot_15.csv")
cs_14 = pd.read_csv("catch_shoot_14.csv")

catch_shoot_pts = []
league_rank = []

# Filter for the Cavaliers and collect the required data
for df in data_frames:
    # Filter for Cleveland Cavaliers
    cavs_info = df[df['TEAM'] == "Cleveland Cavaliers"]
    # Extract 'C&S PTS' and rank
    cands_pts = cavs_info['C&S PTS'].values[0]
    ranks = df['C&S PTS'].rank(ascending=False)
    cavs_rank = ranks[cavs_info.index[0]]

    catch_shoot_pts.append(round(cands_pts))
    league_rank.append(round(cavs_rank))

# %%
import matplotlib.pyplot as plt
years = ['2014', '2015', '2016', '2017', '2018', '2019']
lebron_years = ['2015', '2016', '2017', '2018']

fig, ax1 = plt.subplots(figsize=(10, 6))

bars = ax1.bar(years, catch_shoot_pts, color=(.6, 0.0, 0.0), label='Catch & Shoot Points')
for i, bar in enumerate(bars):
    if years[i] in lebron_years:
        bar.set_color('navy')
        bar.set_label('Catch & Shoot Points with Lebron')
    if years[i] == '2016':
        bar.set_edgecolor('black')  

ax2 = ax1.twinx()
ax2.step(years, league_rank, where='mid', color=(1,0,0), label='League Rank', linewidth=2)
ax2.set_ylabel('League Rank', color = (1,0,0))
ax2.invert_yaxis()  


ax2.annotate('Championship', xy=('2016', league_rank[years.index('2016')]), 
             xytext=(0,-30), textcoords='offset points', 
             ha='center', color='lightblue', fontsize=9)

handles, labels = ax1.get_legend_handles_labels()

unique = [(h, l) for i, (h, l) in enumerate(zip(handles, labels)) if l not in labels[:i]]

ax1.legend(*zip(*unique), loc='upper left', fontsize='small')
ax1.set_xlabel('Year')

ax1.set_ylabel('Team Catch & Shoot Points')
ax1.set_title('Cleveland Cavaliers Catch & Shoot Performance and League Rank (2013-2019)')
plt.savefig('Catch & Shoot', dpi=125)
plt.show()
